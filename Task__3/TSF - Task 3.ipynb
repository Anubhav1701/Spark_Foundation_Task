# %% [markdown]
# # ||             The Spark Foundation            ||         #GRIPAPR21

# %% [markdown]
# ## Name : Preetam Patel

# %% [markdown]
# ## Task : Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’

# %% [markdown]
# ### Step1 : Import Libraries

# %%
#import libraries

import numpy as np
import  pandas as pd
import seaborn as sns
import warnings
from plotnine import *
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2 :  Reading Dataset

# %%
data  =  pd.read_csv("Superstore.csv")

# %%
data.head() # loads first five row of dataset
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.tail()  # loads last five rows of the datasets
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
# Number of rows and columns

data.shape
# Out:
# (9994, 13)

# %%
#Statistical info of dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#Mean , Max, Min , Count value of every column

data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Check total null value, if present

data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### Step 3: Checking for duplicate data , if present then drop it

# %%
# Total duplicate data

data.duplicated().sum()
# Out:
# 17

# %%
# Remove duplicate data

data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# check for the unique data in DataFrame

data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ### Step 4: Dropping the Irrelevant Columns

# %%
# list of coumns  that does affect the profit ...

col = ["Postal Code"]
data = data.drop(columns=col, axis=1)

# %% [markdown]
# ### Step 5 : Checking the relation  b/w various rows and columns

# %%
# Cheching for the relation between columns

data.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
#Covariance of columns

data.cov()
# Out:
#                   Sales    Quantity   Discount        Profit
# Sales     388434.455308  278.459923  -3.627228  69944.096586
# Quantity     278.459923    4.951113   0.003961     34.534769
# Discount      -3.627228    0.003961   0.042622    -10.615173
# Profit     69944.096586   34.534769 -10.615173  54877.798055

# %%
# Again check for first five rows of the DataFrame

data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ###  Step 6 : Data Visulalisation

# %% [markdown]
# ### Bar Grapgh

# %%
plt. figure(figsize=(12, 8))
plt.bar('Sub-Category', "Category",  data = data)
plt.title("Category   vs    Sub-Category")
plt.xlabel("Sub-Category")
plt.ylabel("Category")
plt.xticks(rotation = 90)
plt.show()

# %%
# checking how columns are related to each
data.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ### Histogram Plot

# %%
data.hist(bins = 50, figsize = (12, 8))
plt.show()

# %%
# count total repetative states

data['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x = data['State'])
plt.xticks(rotation = 90)
plt.title("STATE")
plt.show()

# %%
profit_plot = (ggplot(data, aes ( x=  "Sub-Category", y = "Profit", fill = "Sub-Category"))
               + geom_col()
               + coord_flip()
               + scale_fill_brewer(type = "div", palette = "Spectral") 
               + theme_classic() + ggtitle("Pie Chart"))
display(profit_plot)
# Out:
# C:\Anaconda\lib\site-packages\mizani\palettes.py:397: UserWarning: Warning message:Brewer palette Spectral has a maximum of 11 colors Returning the palette you asked for with that many colors
# C:\Anaconda\lib\site-packages\mizani\palettes.py:397: UserWarning: Warning message:Brewer palette Spectral has a maximum of 11 colors Returning the palette you asked for with that many colors
# <ggplot: (187724686665)>

# %%
figsize = (12,9)
sns.pairplot(data, hue = "Sub-Category")

# %% [markdown]
# ##### From the above graph we can say that our data is not normal and contain some outlier also, which we have to treat ....!

# %%
plt.figure(figsize = (10, 5))
sns.lineplot("Discount", "Profit", data = data, color = 'y', label = 'Discount')
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
import plotly.express as ps
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
#tate_code  = { "Alaska" : "AK","Alabama" : "AL, "Arizona" :"AZ", "Arkansas": "AR", "California" : "CA", "Colorado": "CO", "Connecticut

# %% [markdown]
# #####  Now we can analyze sales of random state from each prfit bracket (high profit, low profit, medium profit, high loss, low loss) and try to observe some crucial trends which might help us in inccreasing the sales.

# %%
def state_data_viewer(states):
    
    product_data = data.groupby(["State"])
    for state in states:
        data1 = product_data.get_group(state).groupby(["Category"])
        fig, ax = plt.subplots(1,3, figsize = (28, 5))
        fig.suptitle(state, fontsize = 14)
        ax_index = 0
        for cat in ["Furniture", "Office Supplies", "Technology"]:
            cat_data =  data1.get_group(cat).groupby(["Sub-Category"]).sum()
            sns.barplot( x =cat_data.Profit , y = cat_data.index ,ax = ax[ax_index])
            ax_index += 1
        fig.show()

# %%
states = ["California", "Washington", "Mississippi", "Arizona", "Texas"]
state_data_viewer(states)
# Out:
# <ipython-input-26-15dd0fe3d021>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# <ipython-input-26-15dd0fe3d021>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# <ipython-input-26-15dd0fe3d021>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# <ipython-input-26-15dd0fe3d021>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# <ipython-input-26-15dd0fe3d021>:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# # Thansk You
